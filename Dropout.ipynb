# %%
# !pip install rasterio

import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
import torch
import rasterio
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-b0103ce24b39> in <module>
#       4 import numpy as np
#       5 import os
# ----> 6 import seaborn as sns
#       7 import torch
#       8 import rasterio
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
def read_data(path):
    with rasterio.open(path) as f:
        data = np.rollaxis(f.read(), 0, 3)
        return data
    
def plot_data(data):
    plt.figure()
    plt.imshow(data)
    plt.show()
    
md_1m_2017_dir = "/mnt/blobfuse/esri-naip/v002/md/2017/md_100cm_2017"
i = 0
for tile in os.listdir(md_1m_2017_dir):
    tile_dir = os.path.join(md_1m_2017_dir, tile)
    
    if not os.path.isdir(tile_dir): 
        continue
    
    for patch in os.listdir(tile_dir):
        if '.tif' in patch:
            data_path = os.path.join(tile_dir, patch)
            data = read_data(data_path)
            plot_data(data)
            i += 1

    if i > 15

# %%
# Create UNet

# Create a function to read the data

# split into test, train, finetuning and validation

# train unet on train and evaluate

# create genetic algorthim for weights in first N layers (take number of layers as an argument)

# write group norm function (later)

# finetune loop
# generate dropout configuation
# determine best model
# repeat
